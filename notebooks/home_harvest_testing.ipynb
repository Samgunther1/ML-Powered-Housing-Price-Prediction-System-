# %%
from homeharvest import scrape_property
import pandas as pd

# %%
data = scrape_property(
    location="Cincinnati, OH",
    listing_type="sold",
    past_days=365
)
print(data.shape)
data.head()
# Out:
# (8574, 66)
#                                         property_url property_id  listing_id  \
# 0  https://www.realtor.com/realestateandhomes-det...  4546815824  2992218063
# 1  https://www.realtor.com/realestateandhomes-det...  3941659962  2992082748
# 2  https://www.realtor.com/realestateandhomes-det...  4631073600  2992228631
# 3  https://www.realtor.com/realestateandhomes-det...  4071053610  2987241397
# 4  https://www.realtor.com/realestateandhomes-det...  4195818765  2991545350
#
#                                            permalink   mls   mls_id status  \
# 0  2256-Endovalley-Dr_Cincinnati_OH_45244_M45468-...  CIOH  1870261   SOLD
# 1  8880-Raidersrun-Rd_Cincinnati_OH_45236_M39416-...  CIOH  1870296   SOLD
# 2    3910-Cherry-St_Cincinnati_OH_45223_M46310-73600  CIOH  1870859   SOLD
# 3  2356-Park-Ave-Unit-108_Cincinnati_OH_45206_M40...  CIOH  1857358   SOLD
# 4    2718-Minot-Ave_Cincinnati_OH_45209_M41958-18765  CIOH  1868037   SOLD
#
#   mls_status                                               text  \
# 0       Sold  Beautiful 4 bed, 4.5 bath home in highly desir...
# 1       Sold  Beautiful 6 bed, 5 bath home in a highly sough...
# 2       Sold                                Pending Before Sent
# 3       Sold  Easy living in the timeless Verona building! E...
# 4       Sold  Welcome to the new Oakley-where timeless charm...
#
#            style  ... builder_id builder_name office_id office_mls_set  \
# 0  SINGLE_FAMILY  ...       <NA>         <NA>      <NA>  O-CIOH-COLD23
# 1  SINGLE_FAMILY  ...       <NA>         <NA>      <NA>  O-CIOH-CINB01
# 2  SINGLE_FAMILY  ...       <NA>         <NA>   2254227  O-CIOH-COMY04
# 3         CONDOS  ...       <NA>         <NA>      <NA>  O-CIOH-TARG01
# 4  SINGLE_FAMILY  ...       <NA>         <NA>     27720  O-CIOH-SIBC06
#
#                    office_name                    office_email  \
# 0       Coldwell Banker Realty  bethany.sicurella@cbrealty.com
# 1   Cincinnati Boardwalk, Inc.              boardwalk@fuse.net
# 2             Comey & Shepherd              hydepark@comey.com
# 3  Target Management & Leasing          dan@thetargetgroup.net
# 4      Sibcy Cline - Hyde Park          dhummel@sibcycline.com
#
#                                        office_phones nearby_schools  \
# 0  [{'number': '5134745000', 'type': 'Office', 'p...           <NA>
# 1  [{'number': '(513) 451-4449', 'type': 'Office'...           <NA>
# 2  [{'number': '5133214343', 'type': 'Mobile', 'p...           <NA>
# 3  [{'number': '5137715600', 'type': 'Office', 'p...           <NA>
# 4  [{'number': '5133219922', 'type': 'Office', 'p...           <NA>
#
#                                        primary_photo  \
# 0  https://ap.rdcpix.com/6634e3a4fcdb7ff69dd59653...
# 1  https://ap.rdcpix.com/1ae6b68196f5cc58d1d09e83...
# 2  https://ap.rdcpix.com/9085e8ca7e8aa21589e78a8e...
# 3  https://ap.rdcpix.com/b1b52f80dfea87e3c3e5b6da...
# 4  https://ap.rdcpix.com/10198f40a995b85a36343aee...
#
#                                           alt_photos
# 0  https://ap.rdcpix.com/6634e3a4fcdb7ff69dd59653...
# 1  https://ap.rdcpix.com/1ae6b68196f5cc58d1d09e83...
# 2  https://ap.rdcpix.com/9085e8ca7e8aa21589e78a8e...
# 3  https://ap.rdcpix.com/b1b52f80dfea87e3c3e5b6da...
# 4  https://ap.rdcpix.com/10198f40a995b85a36343aee...
#
# [5 rows x 66 columns]

# %%
data.to_csv('data.csv')

# %%
data.columns
# Out:
# Index(['property_url', 'property_id', 'listing_id', 'permalink', 'mls',
#        'mls_id', 'status', 'mls_status', 'text', 'style', 'formatted_address',
#        'full_street_line', 'street', 'unit', 'city', 'state', 'zip_code',
#        'beds', 'full_baths', 'half_baths', 'sqft', 'year_built', 'days_on_mls',
#        'list_price', 'list_price_min', 'list_price_max', 'list_date',
#        'pending_date', 'sold_price', 'last_sold_date', 'last_sold_price',
#        'last_status_change_date', 'last_update_date', 'assessed_value',
#        'estimated_value', 'tax', 'tax_history', 'new_construction', 'lot_sqft',
#        'price_per_sqft', 'latitude', 'longitude', 'neighborhoods', 'county',
#        'fips_code', 'stories', 'hoa_fee', 'parking_garage', 'agent_id',
#        'agent_name', 'agent_email', 'agent_phones', 'agent_mls_set',
#        'agent_nrds_id', 'broker_id', 'broker_name', 'builder_id',
#        'builder_name', 'office_id', 'office_mls_set', 'office_name',
#        'office_email', 'office_phones', 'nearby_schools', 'primary_photo',
#        'alt_photos'],
#       dtype='object')
